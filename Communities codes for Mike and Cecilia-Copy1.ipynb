# %%
#imports

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from matplotlib import colors as mcolors


CommunitiesOverlap= {'Communities':['PCA-physics','PCA-personal','PCA-science interest','PCA-science research','PCA-informal','PCA-grad school','PCA-arts','Physics-science interest','Physics-science research','Physics-informal','Physics-grad school','Physics-arts'],
                     'Cecilia':[2, 2, 3, 6, 3, 3, 0, 5, 2, 3, 3, 1],
                      'Mike':[1, 0, 4, 3, 4, 1, 2, 6, 17, 1, 1, 0]}

co_df = pd.DataFrame(CommunitiesOverlap)

co_df.plot(kind='bar',x='Communities',y=['Cecilia',"Mike"],rot=20)
plt.ylabel('Percentage (%)')
plt.set_xticks([0.05,0.35,0.85,1.15,1.75, 2.05])
#plt.xlabel('Communities', rotation=40)
plt.title('Communities that overlap with PCA and Physics', fontsize = 14)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-b8d3bf0af576> in <module>
#      16 co_df.plot(kind='bar',x='Communities',y=['Cecilia',"Mike"],rot=20)
#      17 plt.ylabel('Percentage (%)')
# ---> 18 plt.set_xticks([0.05,0.35,0.85,1.15,1.75, 2.05])
#      19 #plt.xlabel('Communities', rotation=40)
#      20 plt.title('Communities that overlap with PCA and Physics', fontsize = 14)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_xticks'
