# %%
#imports

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from matplotlib import colors as mcolors

#Mike is first subject and Cecilia is second
subjects = [0.05,0.35,0.85,1.15,1.75, 2.05] #[0.05,0.35] subject 'locations' for the x axis (start from 0)

#This are percentages from total number of community dimension codes
raw_data = {'insider', 'inbound','peripheral','out','neutral'}

df = pd.DataFrame(raw_data)

insider = [6,8,#AE
         0,0,#ME
         6,17] #NR

inbound = [31,21, #AE
           17,29,#ME
           6,8] #NR
          
peripheral = [7,8,#AE
              0,0,#ME
              0,0]  #NR
          
out = [7,0,#AE
       2,0, #ME
       0,0 ]   #NR
    
neutral = [6,8, #AE
              9,0, #ME
              4,0] #NR


# Choose a suitable bar width:
barWidth = 0.2

# Write subject names
#names = ('Mike', 'Cecilia')
names = ('AE \n Mike ', 
         'AE \n Cecilia','ME \n Mike', 
         'ME \n Cecilia', 
         'NR \n Mike', 'NR \n Cecilia') 

# Plot bars for each code 

plt.bar(subjects,insider,color='mediumvioletred', 
        width=barWidth, label='insider')
plt.bar(subjects,inbound, bottom=insider, color='deeppink', 
        width=barWidth, label='inbound')
plt.bar(subjects, peripheral, bottom=[i+j 
                                      for i,j in zip(insider, inbound)], color='hotpink', 
                              width=barWidth,label='peripheral')
plt.bar(subjects, out, bottom=[i+j+k 
                                 for i,j,k in zip(insider,inbound,peripheral)], 
                         color='palevioletred',width=barWidth, label='out')
plt.bar(subjects, neutral, bottom=[i+j+k+l 
                                  for i,j,k,l in zip(insider,inbound,peripheral, out)]
        ,color='pink', width=barWidth, label='neutral')

# Mutuality of engagement
#plt.bar(subjects, ME_insider, bottom=[i+j+k+l+m 
#                                      for i,j,k,l,m in zip(AE_insider,AE_in,AE_peripheral, AE_neutral, 
#                                 AE_out)],
#                              color='darkgreen', width=barWidth, label='ME insider')
#plt.bar(subjects, ME_in, bottom=[i+j+k+l+m+o 
#                                         for i,j,k,l,m,o in zip(AE_insider,AE_in,AE_peripheral, AE_neutral, 
#                                 AE_out,ME_insider)], 
#                                 color='limegreen', width=barWidth, label='ME inbound')
#plt.bar(subjects, ME_peripheral,bottom=[i+j+k+l+m+o+p 
#                                     for i,j,k,l,m,o,p in zip(AE_insider,AE_in,AE_peripheral, AE_neutral, 
#                                 AE_out,ME_insider,ME_in)] , 
#                             color='lime', width=barWidth, label='ME peripheral')
#plt.bar(subjects, ME_neutral, bottom=[i+j+k+l+m+o+p+r 
#                                 for i,j,k,l,m,o,p,r in zip(AE_insider,AE_in,AE_peripheral, AE_neutral, 
#                                 AE_out, ME_insider,ME_in,
#                                 ME_peripheral)], 
#                         color='yellowgreen',width=barWidth, label='ME neutral')
#plt.bar(subjects, ME_out, bottom=[i+j+k+l+m+o+p+r+s 
#                                  for i,j,k,l,m,o,p,r,s in zip(AE_insider,AE_in,AE_peripheral, AE_neutral, 
#                                 AE_out,ME_insider,ME_in,
#                                 ME_peripheral, ME_neutral)], 
#                          color='palegreen',width=barWidth, 
#                                       label='ME outbound')

# Negotiation of the repertoire
#plt.bar(subjects, NR_insider, bottom=[i+j+k+l+m+o+p+r+s+t 
#                                      for i,j,k,l,m,o,p,r,s,t in zip(AE_insider,AE_in,AE_peripheral, AE_neutral, 
#                                 AE_out,ME_insider,ME_in,
#                                 ME_peripheral, ME_neutral,ME_out)],
#                              color='deepskyblue', width=barWidth,
#                                         label='NR insider')
#plt.bar(subjects, NR_in, bottom=[i+j+k+l+m+o+p+r+s+t+u 
#                                         for i,j,k,l,m,o,p,r,s,t,u in zip(AE_insider,AE_in,AE_peripheral, AE_neutral, 
#                                 AE_out,ME_insider,ME_in,
#                                 ME_peripheral, ME_neutral,ME_out,NR_insider)], 
#                                 color='mediumturquoise',
#                                           width=barWidth, 
#                                           label='NR inbound')
#plt.bar(subjects, NR_peripheral, bottom=[i+j+k+l+m+o+p+r+s+t+u+v 
#                                      for i,j,k,l,m,o,p,r,s,t,u,v in zip(AE_insider,AE_in,AE_peripheral, AE_neutral, 
#                                 AE_out,ME_insider,ME_in,
#                                 ME_peripheral,ME_neutral,ME_out,NR_insider,
#                                 NR_in)], 
#                              color='skyblue',width=barWidth,
#                                             label='NR peripheral')
#plt.bar(subjects, NR_neutral, bottom=[i+j+k+l+m+o+p+r+s+t+u+v+w 
#                                 for i,j,k,l,m,o,p,r,s,t,u,v,w in zip(AE_insider,AE_in,AE_peripheral, AE_neutral, 
#                                 AE_out,ME_insider,ME_in,
#                                ME_peripheral, ME_neutral,ME_out,NR_insider,
#                                 NR_in, NR_peripheral)], 
#                         color='aqua',width=barWidth, label='NR neutral')
#plt.bar(subjects, NR_out, bottom=[i+j+k+l+m+o+p+r+s+t+u+v+w+x 
#                                  for i,j,k,l,m,o,p,r,s,t,u,v,w,x in zip(AE_insider,AE_in,AE_peripheral, AE_neutral, 
#                                 AE_out,ME_insider,ME_in,
#                                 ME_peripheral, ME_neutral,ME_out,NR_insider,
#                                 NR_in,NR_peripheral,NR_neutral)], 
#                          color='paleturquoise',
#                                             width=barWidth, 
#                                             label='NR outbound')

# x axis tick formatting for pre&post data 
ax = plt.axes()
# Hide ticks
ax.tick_params(axis='x', which='both',length=0) 

# Location of the subject with pre&post data
ax.set_xticks([0.05,0.35,0.85,1.15,1.75, 2.05])
ticks = [0, 10, 20, 30, 40, 50, 60, 70, 80]
tick_labels = [0, 10, 20, 30, 40, 50, 60, 70]
ax.set_yticks(ticks)
ax.set_yticklabels(tick_labels, fontsize = 12)

# Label for the subject with pre&post data
#ax.xaxis.set_ticklabels(['Student 1', 'Student 2', 'Student 3', 'Student 4', 'Student 5'])

# Locations and labels for others
#ax.xaxis.set_minor_locator(ticker.FixedLocator(subjects))
ax.xaxis.set_minor_formatter(ticker.FixedFormatter(names))
ax.set_xticklabels(names, fontsize = 12)

plt.xlabel("Community Dimensions", fontsize = 12)
plt.ylabel("Percentage (%)", fontsize = 12)
#plt.title('Community Dimensions \n within PAC', fontsize = 16)
# Add a legend
#plt.legend(loc='upper center', bbox_to_anchor=(1,1), ncol=1, prop={'size':14})
plt.legend(loc='best', bbox_to_anchor=(0.9, -0.1), shadow=True, ncol=3, fontsize= 9)

plt.rcParams['figure.figsize'] = [5.5, 7.5]

# Show graphic
plt.show()
