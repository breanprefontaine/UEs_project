# %%
#imports

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from matplotlib import colors as mcolors

#Mike is first subject and Cecilia is second. Subject 'locations' for the x axis (start from 0)
subjects = [0.05,#PCA/Phys Mike
            0.45,#PCA/Phy Cecilia
            1.05,#PCA/Personal Mike
            1.45,#PCA/Personal Cecilia
            2.05,#PCA/Sci Int Mike
            2.45,#PCA/Sci Int Cecilia
            3.05,#PCA/Sci Research Mike
            3.45,#PCA/Sci Research Cecilia
            4.05,#PCA/Informal Mike
            4.45,#PCA/Informal Cecilia
            5.05,#PCA/Grad school Mike
            5.45,#PCA/Grad school Cecilia  
            6.05,#PCA/Arts Mike
            6.45,#PCA/Arts Cecilia
            7.05,#Phys/Sci Int Mike
            7.45,#Phys/Sci Int Cecilia
            8.05,#Phys/Sci Research Mike
            8.45,#Phys/Sci Research Cecilia
            9.05,#Phys/Informal Mike
            9.45,#Phys/Informal Cecilia
            10.05,#Phys/Grad school Mike
            10.45,#Phys/Grad school Cecilia
            11.05,#Phys/Arts Mike
            11.45] #Phys/Arts Cecilia

#These are percentages from total number of community dimension codes

#Data for Mike: 
mike = {'m_pca_phys', 'm_pca_p','m_pca_si','m_pca_sr','m_pca_inf',
       'm_pca_grad', 'm_pca_arts','m_phys_si','m_phys_sr','m_phys_inf',
       'm_phys_grad', 'm_phys_arts'}

m_df = pd.DataFrame(mike)

m_pca_phys = [1]
m_pca_p = [0]
m_pca_si = [4]
m_pca_sr = [3]
m_pca_inf = [4]
m_pca_grad = [1]
m_pca_arts = [2]

m_phys_si = [6]
m_phys_sr = [17]
m_phys_inf = [1]
m_phys_grad = [1]
m_phys_arts = [0]



#Data for Cecilia
cecilia = {'c_pca_phys', 'c_pca_p','c_pca_si','c_pca_sr','c_pca_inf',
       'c_pca_grad', 'c_pca_arts','c_phys_si','c_phys_sr','c_phys_inf',
       'c_phys_grad', 'c_phys_arts'}

c_df = pd.DataFrame(cecilia)

c_pca_phys = [2]
c_pca_p = [2]
c_pca_si = [3]
c_pca_sr = [6]
c_pca_inf = [3]
c_pca_grad = [3]
c_pca_arts = [0]

c_phys_si = [5]
c_phys_sr = [2]
c_phys_inf = [3]
c_phys_grad = [3]
c_phys_arts = [1]

# Choose a suitable bar width:
barWidth = 0.2

# Write subject names
#names = ('Mike', 'Cecilia')
names = ('PCA-Phys \n Mike ', 
         'PCA-Phys \n Cecilia',
         'PCA-Personal \n Mike', 
         'PCA-Personal \n Cecilia', 
         'PCA-Sci Int \n Mike', 
         'PCA-Sci Int \n Cecilia',
         'PCA-Sci Res \n Mike ', 
         'PCA-Sci Res \n Cecilia',
         'PCA-Inf \n Mike', 
         'PCA-Inf \n Cecilia'
         'PCA-Grad \n Mike ', 
         'PCA-Grad \n Cecilia',
         'PCA-Arts \n Mike', 
         'PCA-Arts \n Cecilia', 
         'Phys-Sci Int \n Mike', 
         'Phys-Sci Int \n Cecilia',
         'Phys-Sci Res \n Mike ', 
         'Phys-Sci Res \n Cecilia',
         'Phys-Inf \n Mike', 
         'Phys-Inf \n Cecilia'
         'Phys-Grad \n Mike ', 
         'Phys-Grad \n Cecilia',
         'Phys-Arts \n Mike', 
         'Phys-Arts \n Cecilia') 

# Plot bars for Mike

# PCA OVERLAP
plt.bar(subjects[0],m_pca_phys,color='darkorchid',width=barWidth, label='Mike')# 'PCA-Phys')
plt.bar(subjects[2],m_pca_p, color='darkorchid', width=barWidth)#, label='PCA-personal')
plt.bar(subjects[4], m_pca_si, color='darkorchid', width=barWidth) #,label='NE-neutral')
plt.bar(subjects[6], m_pca_sr,color='darkorchid',width=barWidth)#, label='CM-in')
plt.bar(subjects[8], m_pca_inf,color='darkorchid', width=barWidth) #, label='CM-out')
plt.bar(subjects[10], m_pca_grad,color='darkorchid', width=barWidth) #, label='CM-neutral')
plt.bar(subjects[12], m_pca_arts,color='darkorchid', width=barWidth) #, label='CM-neutral')


# Phys overlap
plt.bar(subjects[16], m_phys_si, color='darkorchid', width=barWidth) #,label='NE-neutral')
plt.bar(subjects[18], m_phys_sr,color='darkorchid',width=barWidth)#, label='CM-in')
plt.bar(subjects[20], m_phys_inf,color='darkorchid', width=barWidth) #, label='CM-out')
plt.bar(subjects[22], m_phys_grad,color='darkorchid', width=barWidth) #, label='CM-neutral')
plt.bar(subjects[24], m_phys_arts,color='darkorchid', width=barWidth) #, label='CM-neutral')

# Plot bars for Cecilia

# PCA OVERLAP
plt.bar(subjects[1], c_pca_phys,color='darkturquoise',width=barWidth, label='Cecilia')# 'PCA-Phys')
plt.bar(subjects[3], c_pca_p, color='darkturquoise', width=barWidth)#, label='PCA-personal')
plt.bar(subjects[5], c_pca_si, color='darkturquoise', width=barWidth) #,label='NE-neutral')
plt.bar(subjects[7], c_pca_sr,color='darkturquoise',width=barWidth)#, label='CM-in')
plt.bar(subjects[9], c_pca_inf,color='darkturquoise', width=barWidth) #, label='CM-out')
plt.bar(subjects[11], c_pca_grad,color='darkturquoise', width=barWidth) #, label='CM-neutral')
plt.bar(subjects[13], c_pca_arts,color='darkturquoise', width=barWidth) #, label='CM-neutral')


# Phys overlap
plt.bar(subjects[15], c_phys_si, color='darkturquoise', width=barWidth) #,label='NE-neutral')
plt.bar(subjects[17], c_phys_sr,color='darkturquoise',width=barWidth)#, label='CM-in')
plt.bar(subjects[19], c_phys_inf,color='darkturquoise', width=barWidth) #, label='CM-out')
plt.bar(subjects[21], c_phys_grad,color='darkturquoise', width=barWidth) #, label='CM-neutral')
plt.bar(subjects[23], c_phys_arts,color='darkturquoise', width=barWidth) #, label='CM-neutral')

# x axis tick formatting for pre&post data 
ax = plt.axes()
# Hide ticks
ax.tick_params(axis='x', which='both',length=0) 


# Location of the subject
ax.set_xticks([0.05,0.45,1.05,1.45,2.05, 2.45,3.05,3.45,4.05,4.45,5.05,5.45,6.05,6.45,7.05,7.45,8.05,8.45,9.05,9.45,10.05,10.45,11.05,11.45])
ticks = [0, 10, 20, 30, 40, 50]
tick_labels = [0, 10, 20, 30, 40, 50]
ax.set_yticks(ticks)
ax.set_yticklabels(tick_labels, fontsize = 12)

# Label for the subject with pre&post data
#ax.xaxis.set_ticklabels(['Student 1', 'Student 2', 'Student 3', 'Student 4', 'Student 5'])

# Locations and labels for others
#ax.xaxis.set_minor_locator(ticker.FixedLocator(subjects))
ax.xaxis.set_minor_formatter(ticker.FixedFormatter(names))
ax.set_xticklabels(names, fontsize = 10)

plt.xlabel("Communities overlap", fontsize = 12)
plt.ylabel("Percentage (%)", fontsize = 12)
#plt.title('Community Dimensions \n within PAC', fontsize = 16)
# Add a legend
#plt.legend(loc='best', bbox_to_anchor=(1,1), ncol=1, prop={'size':14})
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), shadow=True, ncol=5, fontsize= 8)

plt.rcParams['figure.figsize'] = [26.5, 26.5]

# Show graphic
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-2c6fe639ca4f> in <module>
#     126 plt.bar(subjects[20], m_phys_inf,color='darkorchid', width=barWidth) #, label='CM-out')
#     127 plt.bar(subjects[22], m_phys_grad,color='darkorchid', width=barWidth) #, label='CM-neutral')
# --> 128 plt.bar(subjects[24], m_phys_arts,color='darkorchid', width=barWidth) #, label='CM-neutral')
#     129
#     130 # Plot bars for Cecilia
#
# IndexError: list index out of range
